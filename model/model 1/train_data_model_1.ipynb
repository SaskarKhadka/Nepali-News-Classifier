# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import codecs, json

# %% [markdown]
# I forgot to save the result generated when the model was trained. So, I manually created "data.csv" from the training logs

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#      loss  accuracy  f1_score  precision  recall  val_loss  val_accuracy  \
# 0  1.4889    0.5479    0.5301     0.8974  0.1635    0.9658        0.7079
# 1  0.8372    0.7410    0.7350     0.8761  0.5254    0.7957        0.7467
# 2  0.6506    0.7979    0.7953     0.8698  0.7024    0.7209        0.7649
# 3  0.4984    0.8473    0.8458     0.8854  0.8015    0.6904        0.7723
# 4  0.3938    0.8814    0.8806     0.9056  0.8558    0.6954        0.7743
#
#    val_f1_score  val_precision  val_recall
# 0        0.6904         0.8724      0.4198
# 1        0.7411         0.8494      0.6207
# 2        0.7611         0.8230      0.7060
# 3        0.7708         0.8101      0.7380
# 4        0.7735         0.8038      0.7486

# %% [markdown]
# Now lets crete some plots from this data

# %%
plt.plot(data['loss'])
plt.plot(data['val_loss'])
plt.title('Training and Validation loss (CCE) vs. Epochs')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("../images/loss plot")
plt.show()

# %%
plt.plot(data['accuracy'])
plt.plot(data['val_accuracy'])
plt.title('Training and Validation accuracy vs. Epochs')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("../images/accuracy plot")
plt.show()

# %%
plt.plot(data['f1_score'])
plt.plot(data['val_f1_score'])
plt.title('Training and Validation F1 Score vs. Epochs')
plt.ylabel('f1 score')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("../images/f1 score plot")
plt.show()

# %%
plt.plot(data['precision'])
plt.plot(data['val_precision'])
plt.title('Training and Validation precision vs. Epochs')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("../images/precision plot")
plt.show()

# %%
plt.plot(data['recall'])
plt.plot(data['val_recall'])
plt.title('Training and Validation recall vs. Epochs')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("../images/recall plot")
plt.show()
